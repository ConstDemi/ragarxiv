# %%
from dotenv import load_dotenv
import os
from openai import OpenAI
from ragas.llms import llm_factory
from langchain_huggingface import HuggingFaceEmbeddings
from datasets import Dataset
import pandas as pd

# Импортируем классы
from ragas.metrics import (
    ContextPrecision,
    ContextRecall,
    AnswerRelevancy,
    Faithfulness
)
from ragas import evaluate

load_dotenv()

client = OpenAI(
    api_key=os.getenv('API_KEY'),
    base_url="https://foundation-models.api.cloud.ru/v1"
)
llm = llm_factory("Qwen/Qwen3-235B-A22B-Instruct-2507", provider="openai", client=client, max_tokens=8192)
embeddings = HuggingFaceEmbeddings(
    model_name="Qwen/Qwen3-Embedding-0.6B"  # model_name вместо model
)

df = pd.read_parquet('../data/ragas/gd_filled.parquet')
dataset = Dataset.from_pandas(df)

# В версии 0.4.3 нужно передавать llm в МЕТРИКИ, а НЕ в evaluate()
result = evaluate(
    dataset=dataset,
    metrics=[
        ContextPrecision(llm=llm),
        ContextRecall(llm=llm),
        AnswerRelevancy(llm=llm, embeddings=embeddings),
        Faithfulness(llm=llm)
    ]
    # БЕЗ llm= и embeddings= здесь!
)

print(result)
# Out:
# C:\Users\Life4five\AppData\Local\Temp\ipykernel_7080\2479147755.py:10: DeprecationWarning: Importing ContextPrecision from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import ContextPrecision
#   from ragas.metrics import (
# C:\Users\Life4five\AppData\Local\Temp\ipykernel_7080\2479147755.py:10: DeprecationWarning: Importing ContextRecall from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import ContextRecall
#   from ragas.metrics import (
# C:\Users\Life4five\AppData\Local\Temp\ipykernel_7080\2479147755.py:10: DeprecationWarning: Importing AnswerRelevancy from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import AnswerRelevancy
#   from ragas.metrics import (
# ...
